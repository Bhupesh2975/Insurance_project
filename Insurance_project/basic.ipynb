# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\BHUPESH\Desktop\Insurance_Project\insurance_cleaned.csv')

# %%
df
# Out:
#       age  gender     bmi  children  smoker  region      charges
# 0      19       0  27.900         0       1       3  16884.92400
# 1      18       1  33.770         1       0       2   1725.55230
# 2      28       1  33.000         3       0       2   4449.46200
# 3      33       1  22.705         0       0       1  21984.47061
# 4      32       1  28.880         0       0       1   3866.85520
# ...   ...     ...     ...       ...     ...     ...          ...
# 1332   50       1  30.970         3       0       1  10600.54830
# 1333   18       0  31.920         0       0       0   2205.98080
# 1334   18       0  36.850         0       0       2   1629.83350
# 1335   21       0  25.800         0       0       3   2007.94500
# 1336   61       0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.dropna(inplace=True)
x = df.drop('charges',axis=1)
y= df[['charges']]

# %%
x
# Out:
#       age  gender     bmi  children  smoker  region
# 0      19       0  27.900         0       1       3
# 1      18       1  33.770         1       0       2
# 2      28       1  33.000         3       0       2
# 3      33       1  22.705         0       0       1
# 4      32       1  28.880         0       0       1
# ...   ...     ...     ...       ...     ...     ...
# 1332   50       1  30.970         3       0       1
# 1333   18       0  31.920         0       0       0
# 1334   18       0  36.850         0       0       2
# 1335   21       0  25.800         0       0       3
# 1336   61       0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1332  10600.54830
# 1333   2205.98080
# 1334   1629.83350
# 1335   2007.94500
# 1336  29141.36030
#
# [1337 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1069, 6), (268, 6), (1069, 1), (268, 1))

# %%
from sklearn.linear_model import LinearRegression 
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.7297182858804965

# %%
lr.score(x_test, y_test)
# Out:
# 0.8068466322629112

# %%
pred = lr.predict(x_test)

# %%
pred = pd.DataFrame(pred )

# %%
pred
# Out:
#                 0
# 0     8080.450186
# 1     5592.871120
# 2    14378.298655
# 3    31731.819541
# 4     9158.356944
# ..            ...
# 263  16952.682449
# 264  15496.907965
# 265   6303.385531
# 266  38248.332909
# 267   8246.876763
#
# [268 rows x 1 columns]

# %%
y_test
# Out:
#           charges
# 899    8688.85885
# 1063   5708.86700
# 1255  11436.73815
# 298   38746.35510
# 237    4463.20510
# ...           ...
# 534   13831.11520
# 542   13887.20400
# 759    3925.75820
# 1283  47403.88000
# 1284   8534.67180
#
# [268 rows x 1 columns]

# %%
x_test
# Out:
#       age  gender     bmi  children  smoker  region
# 899    49       1  22.515         0       0       0
# 1063   29       0  25.600         4       0       3
# 1255   51       0  36.385         3       0       1
# 298    31       1  34.390         3       1       1
# 237    31       1  38.390         2       0       2
# ...   ...     ...     ...       ...     ...     ...
# 534    64       1  40.480         0       0       2
# 542    63       0  36.300         0       0       2
# 759    22       0  34.580         2       0       0
# 1283   61       1  36.300         1       1       3
# 1284   47       0  24.320         0       0       0
#
# [268 rows x 6 columns]

# %%
pd.concat([pred, y_test])
# Out:
#                  0     charges
# 0      8080.450186         NaN
# 1      5592.871120         NaN
# 2     14378.298655         NaN
# 3     31731.819541         NaN
# 4      9158.356944         NaN
# ...            ...         ...
# 534            NaN  13831.1152
# 542            NaN  13887.2040
# 759            NaN   3925.7582
# 1283           NaN  47403.8800
# 1284           NaN   8534.6718
#
# [536 rows x 2 columns]

# %%
import joblib
joblib.dump(lr,"insurance_model.lb")
# Out:
# ['insurance_model.lb']

# %%
# joblib.load   >>>>> bdd me bina train kiye use karne ke liye

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.svm import SVR
svr = SVR()


svr.fit(x_train,y_train)
# Out:
# c:\Users\BHUPESH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
svr.score(x_test,y_test)
# Out:
# -0.08483994285299712

# %%
svr.score(x_train,y_train)
# Out:
# -0.1025888275538267

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knr.score(x_test,y_test)
# Out:
# 0.12658441962295996

# %%
knr.score(x_train,y_train)
# Out:
# 0.40286424886539784

# %%
# from sklearn.datasets import load_iris
# x,y = load_iris(return_X_y=True)
# x

# %%
# y
